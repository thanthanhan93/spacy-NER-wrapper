# %%
import pandas as pd
import json
import re
from nltk.tokenize import RegexpTokenizer

# %%
def __tokenize(text: str) -> str:
        """tokenize a text into tokens and join them on ' '

        :param text: text to be tokenized
        :type text: str
        :return: preprocessed string
        :rtype: str
        """
        # for now simple tokenizer keeping only word characters with length > 1
        tokenizer = RegexpTokenizer(r'\w+')
        token_list = tokenizer.tokenize(text)

        return ' '.join([w.lower() for w in token_list if len(w) >= 1])

def process_text_data(df, text_columns):
        """
        process text data
        :param text_columns: list[str]
        :return: self object
        :rtype: TProcessorIngredient
        """
        if df is not None:
            #df = df.dropna()
            df = df.fillna('')
            df[text_columns] = df[text_columns].astype(str)
            df['features'] = df[text_columns].apply(lambda x: ' '.join(x), axis=1)

            df['features'] = df['features']\
                .str.lower()\
                .str.replace('ø? ?[0-9]*(,|\\.)*[0-9]+ ?(l|ml|cl|g|mg|cm|gr|er) ', ' ')\
                .str.replace('\'s', ' ')\
                .str.replace('(7 up|7-up)', '7up')\
                .str.replace('<br> ?(-|\\+)?', ' ')

            df['features'] = \
                df['features'].str.split(' ')

            df['features'] = \
                [[re.sub('\W+', ' ', each) for each in t] for t in df['features']]

            df['features'] = \
                [[re.sub('[0-9]+ ?$', ' ', each) for each in t] for t in df['features']]

            df['features'] = \
                [[word.strip() for word in s] for s in df['features']]

            df['features'] = \
                [[word for word in s if len(word) >= 2] for s in df['features']]

            df['features'] = \
                df['features'].apply(lambda s: list(filter(None, s)))

            df['features'] = \
                [' '.join(s) for s in df['features'].values]

            # df['features'] = [spell_correction.naive_correction(word) for word in df['features'].values]

            df['features_token'] = df['features'].apply(__tokenize)

        return df
    
def doccano_to_defined_format(train_path):
    f = open(train_path, 'r', encoding='utf-8')
    lines = []
    for line in f:
        line = json.loads(line)
        
        text = line['text']
        token_offsets = line['labels']
        tokens = []
        for token_off in token_offsets:
            token = text[token_off[0]:token_off[1]].strip()
            tokens.append([token, [token_off[0], token_off[0]+len(token), token_off[-1]]])
        lines.append([text, tokens])
    return lines



def mapping_entities_to_unprocessed_data(row):
    text = row.original_name
    tags = row.tag
    tags = sorted(row.tag, key=lambda x: x[1][0])
    entities = []
    for tag in tags:
        tag_tokens = tag[0].split(' ')
        tag_loc = tag[1]
        start_loc = 0
        end_loc = entities[-1][1] if len(entities)>0 else 0
        flag = 1
        try:
            for token in tag_tokens:
                # baguettebrot - baguette + brot
                patterns = re.compile( r'\b' + token + r'\w*\b')
                start_loc_new, end_loc = patterns.search(text, end_loc).span()
                if flag:
                    start_loc=start_loc_new
                    flag =0

            entities.append([start_loc, end_loc, tag_loc[-1]])
            if(end_loc-start_loc < tag_loc[1]-tag_loc[0]):
                print("MATCHED TOKEN SORTER THAN ORIGINAL: ",
                      text, tag,
                      '(', start_loc, ',', end_loc, ')')
        except:
            continue
            print("MIDDLE STRING ING", text, tag)
        
    
    matched = 0
    if(len(entities) == len(tags)):
        matched = 1
        
    start_len = len(set([item[0] for item in entities]))
    end_len = len(set([item[1] for item in entities]))
    ent_len = len(entities) 
    if ((start_len != ent_len) | (end_len != ent_len)):
        print("DUPLICATES PROBLEM: ", text)
        print(tags)
        print(' |'.join([' |'.join([text[entity[0]:entity[1]],
                                    str(entity[0]),
                                    str(entity[1])]) for entity in entities]))
        print('')
        
    return pd.Series({'text':row.naam + ' ' + row.omschrijving, 'entities':entities, 'match_all': matched})

def get_file_path(lst):
    return '/'.join(lst)

# %%
def save_to_file(df, file_name):
    f = open(filename, 'w')
    for _, row in df[['text', 'entities']].rename(columns ={'entities':'labels'}).iterrows():
        tmp = json.dumps(row.to_dict(), ensure_ascii=False)
        f.write(tmp)
        f.write("\n")

# %%
meta_data = {
    "path_ner_data_folder": "ner_datasets",
    "path_annotated_data_file" : "FULL_SET_CORRECTED.json1",
    "path_data_folder": "data",
    "path_prod_file": "product_DE.csv"
}

# %%
df = pd.read_csv('data/verified_original_data.csv')

# %%
df['origin_lpn'] = df['origin_lpn'].str.strip()

# %%
df = df.drop_duplicates(subset='origin_lpn')

# %%
df_train = pd.DataFrame(doccano_to_defined_format('ner_datasets/TRAIN_FINAL_CORRECTED.json1'), columns=['origin_lpn', 'tag'])
df_train = df_train.drop_duplicates(subset='origin_lpn')

# %%
df.drop(['processed_text', 'tag'], axis=1).merge(df_train, on='origin_lpn')#.to_csv('data/verified_original_data_new.csv', index=False)
# Out:
#       product_id                                               naam  \
# 0        5874771                                             Sprite
# 1        5874771                                             Sprite
# 2       18768851                                             Sprite
# 3       18768851                                             Sprite
# 4       10929132                                             Sprite
# ...          ...                                                ...
# 4134   273394278                        Pizza Fritz [Klein, Ø 20cm]
# 4135   281334468  Ben & Jerry's Salted Caramel Brownie Topped [5...
# 4136   240625374                                          Kiddy Box
# 4137    66798435        Ben & Jerry's Chocolate Fudge Brownie 500ml
# 4138   273495568                    Pizza Ramazotti [Klein, Ø 20cm]
#
#                                            omschrijving  \
# 0                                                 1.0 l
# 1                                                 1.0 l
# 2                                                0,33 l
# 3                                                0,33 l
# 4                                                 0,5 l
# ...                                                 ...
# 4134        mit Gyros, Peperoni, Zwiebeln und Thunfisch
# 4135  Das Salted Caramel Brownie Topped besteht aus ...
# 4136  • 3 Chicken Nuggets <br> • Pommes frites <br> ...
# 4137         sündhaft cemige Schokoladenkuchen-Eiscreme
# 4138  mit Salami, Schinken, Champignons, milden Pepe...
#
#                                               lower_lpn  \
# 0                                          sprite 1.0 l
# 1                                          sprite 1.0 l
# 2                                         sprite 0,33 l
# 3                                         sprite 0,33 l
# 4                                          sprite 0,5 l
# ...                                                 ...
# 4134  pizza fritz [klein, ø 20cm] mit gyros, peperon...
# 4135  ben & jerry's salted caramel brownie topped [5...
# 4136  kiddy box • 3 chicken nuggets <br> • pommes fr...
# 4137  ben & jerry's chocolate fudge brownie 500ml sü...
# 4138  pizza ramazotti [klein, ø 20cm] mit salami, sc...
#
#                                              origin_lpn  \
# 0                                          Sprite 1.0 l
# 1                                          Sprite 1.0 l
# 2                                         Sprite 0,33 l
# 3                                         Sprite 0,33 l
# 4                                          Sprite 0,5 l
# ...                                                 ...
# 4134  Pizza Fritz [Klein, Ø 20cm] mit Gyros, Peperon...
# 4135  Ben & Jerry's Salted Caramel Brownie Topped [5...
# 4136  Kiddy Box • 3 Chicken Nuggets <br> • Pommes fr...
# 4137  Ben & Jerry's Chocolate Fudge Brownie 500ml sü...
# 4138  Pizza Ramazotti [Klein, Ø 20cm] mit Salami, Sc...
#
#                                                     tag
# 0                             [[Sprite, [0, 6, Brand]]]
# 1                             [[Sprite, [0, 6, Brand]]]
# 2                             [[Sprite, [0, 6, Brand]]]
# 3                             [[Sprite, [0, 6, Brand]]]
# 4                             [[Sprite, [0, 6, Brand]]]
# ...                                                 ...
# 4134  [[Pizza, [0, 5, Ing]], [Gyros, [32, 37, Ing]],...
# 4135  [[Ben & Jerry, [0, 11, Brand]], [Salted Carame...
# 4136  [[Chicken Nuggets, [14, 29, Ing]], [Pommes fri...
# 4137  [[Ben & Jerry, [0, 11, Brand]], [Chocolate Fud...
# 4138  [[Pizza, [0, 5, Ing]], [Salami, [36, 42, Ing]]...
#
# [4139 rows x 6 columns]

# %%
df_train
# Out:
#                                               origin_lpn  \
# 0                                            Sprite 1,0l
# 1                                           Sprite 0,33l
# 2                                            Sprite 1.5l
# 3                                              Sprite 1l
# 4                                            Sprite 0,5l
# ...                                                  ...
# 10321  Ben & Jerry's Chocolate Fudge Brownie 500ml sü...
# 10322  Pizza Ramazotti [Klein, Ø 20cm] mit Salami, Sc...
# 10323                               Warsteiner Pils 0,5l
# 10324                               Warsteiner Pils 0,3l
# 10325                              Warsteiner Pils 0,33l
#
#                                                      tag
# 0                              [[Sprite, [0, 6, Brand]]]
# 1                              [[Sprite, [0, 6, Brand]]]
# 2                              [[Sprite, [0, 6, Brand]]]
# 3                              [[Sprite, [0, 6, Brand]]]
# 4                              [[Sprite, [0, 6, Brand]]]
# ...                                                  ...
# 10321  [[Ben & Jerry, [0, 11, Brand]], [Chocolate Fud...
# 10322  [[Pizza, [0, 5, Ing]], [Salami, [36, 42, Ing]]...
# 10323  [[Warsteiner, [0, 10, Brand]], [Pils, [11, 15,...
# 10324  [[Warsteiner, [0, 10, Brand]], [Pils, [11, 15,...
# 10325  [[Warsteiner, [0, 10, Brand]], [Pils, [11, 15,...
#
# [10326 rows x 2 columns]

# %%
data_annotation = doccano_to_defined_format(get_file_path(
    [meta_data['path_ner_data_folder'], 
     meta_data['path_annotated_data_file']]))
df_annotation = pd.DataFrame(data_annotation, columns = ['processed_text', 'tag'])
print(df_annotation.shape)
df_annotation = df_annotation.drop_duplicates(subset='processed_text')
print(df_annotation.shape)
# Out:
# (3999, 2)
# (2754, 2)

# %%
df_original = pd.read_csv(get_file_path(
    [meta_data['path_data_folder'], 
     meta_data['path_prod_file']])).fillna('')
df_original.shape
# Out:
# (9459170, 3)

# %%
df_original['original_name'] = df_original.apply(lambda x: x.naam + ' ' + x.omschrijving, axis=1).str.lower() 
df_original = df_original.drop_duplicates(subset='original_name')
df_original.shape
# Out:
# (4828107, 4)

# %%
df_original = process_text_data(df_original, ['original_name'])
df_original.shape
# Out:
# (4828107, 6)

# %%
df_final[['product_id', 'naam', 'omschrijving', 'original_name', 'processed_text', 'tag']].to_csv('data/verified_original_data.csv', index=False)

# %%
df_final = df_annotation.merge(df_original, left_on='processed_text', right_on='features_token')
df_final.shape
# Out:
# (12977, 8)

# %%
df_result = df_final.apply(mapping_entities_to_unprocessed_data , axis=1)
df_result.shape
# Out:
# (12977, 3)

# %%
df_result
# Out:
#                                                     text  \
# 0                                           Sprite 1,0l
# 1                                          Sprite 0,33l
# 2                                           Sprite 1.5l
# 3                                             Sprite 1l
# 4                                           Sprite 0,5l
# ...                                                  ...
# 12972  Ben & Jerry's Strawberry Cheesecake 500ml Erdb...
# 12973  Ben & Jerry's Strawberry Cheesecake 100ml Erdb...
# 12974  Ben & Jerry's Strawberry Cheesecake 500ml Erdb...
# 12975  Ouzo Spezial-Teller mit Gyros, Schnitzel, Hähn...
# 12976  Ben & Jerry's Blondie Brownie 500ml Vanille- &...
#
#                                                 entities  match_all
# 0                                        [[0, 6, Brand]]          1
# 1                                        [[0, 6, Brand]]          1
# 2                                        [[0, 6, Brand]]          1
# 3                                        [[0, 6, Brand]]          1
# 4                                        [[0, 6, Brand]]          1
# ...                                                  ...        ...
# 12972  [[0, 11, Brand], [14, 35, Flavor], [115, 126, ...          1
# 12973  [[0, 11, Brand], [14, 35, Flavor], [115, 126, ...          1
# 12974  [[0, 11, Brand], [14, 35, Flavor], [114, 125, ...          1
# 12975  [[0, 4, Ing], [24, 29, Ing], [31, 40, Ing], [4...          1
# 12976  [[0, 11, Brand], [14, 29, Flavor], [159, 170, ...          1
#
# [12977 rows x 3 columns]

# %%
save_to_file(df_result, 'doccano_format_2.jsonl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-4345b9b5ea39> in <module>
# ----> 1 save_to_file(df_result, 'doccano_format_2.jsonl')
#
# <ipython-input-24-ec60c8d6678f> in save_to_file(df, file_name)
#       1 def save_to_file(df, file_name):
# ----> 2     f = open(filename, 'w')
#       3     for _, row in df[['text', 'entities']].rename(columns ={'entities':'labels'}).iterrows():
#       4         tmp = json.dumps(row.to_dict(), ensure_ascii=False)
#       5         f.write(tmp)
#
# NameError: name 'filename' is not defined

# %%
# Out:
# [['Sprite 1,0l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,33l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1.5l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,5l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,2l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1.0 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1,5l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite - 1,0 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,33 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0.33l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1,5 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1.0l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite ', {'entities': [[0, 6, 'Brand']]}],
#  ['1l Sprite ', {'entities': [[3, 9, 'Brand']]}],
#  ['Sprite 0,3l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1.00 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,5 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0.5l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1,0 ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite, 0,33l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1,0 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite  0,33l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1 L', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0.5 L', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1,0 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,2 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite0,5l ', {'entities': [[0, 7, 'Brand']]}],
#  ['Sprite 0,33 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,5 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1,5 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite1,0l ', {'entities': [[0, 7, 'Brand']]}],
#  ['Sprite 1,25l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite - 0.33l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,4 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite - 1.5l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,33 l  0,33 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite, 1,0l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite [0,33 L] ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,7l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite, 1 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite1l ', {'entities': [[0, 8, 'Brand']]}],
#  ['Sprite 0,4l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite [0,5 l] ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,5 ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,33l  ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite, 1,0 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite, 0,33 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite (1,0 l) ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite [1,0 l] ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,25l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite - 0,2l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,20 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,1l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 2l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0.2l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite, 1L ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite0.33l ', {'entities': [[0, 7, 'Brand']]}],
#  ['Sprite, 0,3l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite, 0,5l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite [1 l] ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1.5 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite, 1,25l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0.3l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,7 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite  0,2 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,5 l 0,5 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite - 1,0l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,33 l 0,33 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite - 0,5l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0.3 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0.2 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1.0 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0.5 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,75l ', {'entities': [[0, 6, 'Brand']]}],
#  ['0,33 l Sprite ', {'entities': [[7, 13, 'Brand']]}],
#  ['Sprite 0.33 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,25 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite - 0.5l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite, 0,2l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite  0,33 l', {'entities': [[0, 6, 'Brand']]}],
#  ['1,5l Sprite ', {'entities': [[5, 11, 'Brand']]}],
#  ['Sprite 0,33 ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1,00 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1,5 l 1,5 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite, 0,20l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1.5 L', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0.33 ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite (1.5 l) ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,2 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite  1,0l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 10l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite1l  ', {'entities': [[0, 8, 'Brand']]}],
#  ['Sprite 1,0l 1,0 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite [0,4 l] ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite - 0,2 L ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite [0,2 l] ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite, 1.0l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite ( 1 L ) ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite – 1,0l ', {'entities': [[0, 6, 'Brand']]}],
#  ['1,25l Sprite ', {'entities': [[6, 12, 'Brand']]}],
#  ['Sprite - 0,5 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 2,0l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0.33 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1,0 l 1,0 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite1,25l ', {'entities': [[0, 7, 'Brand']]}],
#  ['Sprite (0,33 l) ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite, 1,00 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite - 0.33 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1,25 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite, 1,50L ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite, 1,5l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,3 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1l  ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite  0,33 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite [0,3 L] ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1,0l  ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1.25 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite - 0.5 L ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite, 1.5l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1,25 L ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite, 0,25l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite - 1 L ', {'entities': [[0, 6, 'Brand']]}],
#  ['0,33l Sprite ', {'entities': [[6, 12, 'Brand']]}],
#  ['Sprite - 1.0 L ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1,0l =3,00 €/l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0 ,5l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite - 1.0l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite - 1l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite, 0.2l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1,5l 1.5 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1.0', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 12 x 1,0l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0.2 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1,0l 1 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1,5 ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1.00 l', {'entities': [[0, 6, 'Brand']]}],
#  ['SPRITE (1 L.) ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,50 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite (0,5 l) ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite  1,0 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 033l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1 l + 0,15 €', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite0,33l ', {'entities': [[0, 7, 'Brand']]}],
#  ['Sprite0,33 l ', {'entities': [[0, 7, 'Brand']]}],
#  ['Sprite, 1,5 L ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite  0,4 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite   0,33l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1,00 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite - 0,4 L ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1,00l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite  1 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,33l 0,33 l', {'entities': [[0, 6, 'Brand']]}],
#  ['1,0 l Sprite ', {'entities': [[6, 12, 'Brand']]}],
#  ['Sprite 0.3 l', {'entities': [[0, 6, 'Brand']]}],
#  ['0,5l Sprite ', {'entities': [[5, 11, 'Brand']]}],
#  ['Sprite 1.0 ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,5 l  0,5 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite  1,0 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1 l 1 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite - 0,33l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1 l 1,0 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1 ,0l ', {'entities': [[0, 6, 'Brand']]}],
#  ['SPRITE (0,5 L.) ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite (1 l) ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite (1,5) ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite  12 x 1 ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,33 l  ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite  ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1 l  1,0 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite  1,00 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0.25l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,33ml ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 12 x 0,5l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,50l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0.1l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,5l 0,5', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1.00l ', {'entities': [[0, 6, 'Brand']]}],
#  ['5 x Sprite 1,0l ', {'entities': [[4, 10, 'Brand']]}],
#  ['Sprite 24 x 0,2l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite, 500 ml ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,33l 1,0 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite  1l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0.33l  ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,33l 1,00 L', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite [1,5 l] ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1,00 ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite (0,5) ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite – 0,33l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,5l 1l 4,00', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1,25 ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0.7l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,5l  ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite  0,5 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite  0,3 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,2 l [1 l] ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1.25 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,5l =4,00 €/l', {'entities': [[0, 6, 'Brand']]}],
#  ['4 x Sprite à 1,0l ', {'entities': [[4, 10, 'Brand']]}],
#  ['Sprite 0.7 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['G4 - Sprite 0,5l ', {'entities': [[5, 11, 'Brand']]}],
#  ['Sprite1.0l ', {'entities': [[0, 7, 'Brand']]}],
#  ['Sprite 0.4l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite - 1,0 L 1,0 L', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite (1,5 l) ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite - 12 x 0,5l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,33l [0,33 l] ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 24 x 0,20l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,1 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,22l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite - 12 x 1,0l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite1,0 l ', {'entities': [[0, 7, 'Brand']]}],
#  ['Sprite 0,20l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite - 1.5 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,33l 8 ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite, 1,0 ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite (1.0 l) ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 24 x 0,33l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,33l 0,33l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite - 10 x 1,5l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite - 24 x 0,2l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite - 24 x 0,33l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite, 0,5 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,1 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1,,0l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1, l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite [0,25 l] ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 20 x 0,50l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1,0 l  ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 2,5l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite, 1,25 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite, 24 x 0,33 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1,0l 1,0l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite , 0,3L ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite,1,0 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 330ml ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite n1,0l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1,50 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite,1 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1, 0 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite,1,0l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite, 0.5l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite [1,00 L] ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,33l [1,0 l] ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite, 0,3 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,3 ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,4 l  ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1,5l 1,0l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,33 l l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,9l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 1,50l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite, 0,2 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,33l 12 x 1 L', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 2 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite [1,25 l] ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0.33 0.33l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,7 L ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0, 3 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,2 ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,40 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite  1.0 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite, 1,0l 1,0l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,33l 1.5 L', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite, 0,4l ', {'entities': [[0, 6, 'Brand']]}],
#  ['G4 - Sprite 1,0l ', {'entities': [[5, 11, 'Brand']]}],
#  ['Sprite 1,0l 0,33l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,33l 1 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0, 33 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,2', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite, 1,00l ', {'entities': [[0, 6, 'Brand']]}],
#  ['3 Sprite 0,33l ', {'entities': [[2, 8, 'Brand']]}],
#  ['Sprite 1 ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite , 1 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 12 x 1l ', {'entities': [[0, 6, 'Brand']]}],
#  ['*Sprite, 1,0l ', {'entities': [[1, 7, 'Brand']]}],
#  ['*Sprite, 0,33l ', {'entities': [[1, 7, 'Brand']]}],
#  ['Sprite 0,5l 0,33l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,33l 1.0 l', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,30 l ', {'entities': [[0, 6, 'Brand']]}],
#  ['Sprite 0,5 l 17 ', {'entities': [[0, 6, 'Brand']]}],
#  ['Pizza Fische [Jumbo, Ø 40cm] mit Tomatenscheiben, Käse, Broccoli, Spinat, frischen Pilzen, frischer Paprika und Mozzarella',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [33, 48, 'Ing'],
#     [50, 54, 'Ing'],
#     [56, 64, 'Ing'],
#     [66, 72, 'Ing'],
#     [83, 89, 'Ing'],
#     [100, 107, 'Ing'],
#     [112, 122, 'Ing']]}],
#  ['Pizzabrötchen mit Ananas ',
#   {'entities': [[0, 13, 'Ing'], [18, 24, 'Ing']]}],
#  ['Pizzabrötchen 12 mit Ananas',
#   {'entities': [[0, 13, 'Ing'], [21, 27, 'Ing']]}],
#  ['Murgh Sahi-Korma mit Hühnerstücken nach Moghul-Art, milder Sauce, Gewürzen, Sahne, Mandeln, Kokosnuss , Cashewnüssen und Reis',
#   {'entities': [[21, 34, 'Ing'],
#     [76, 81, 'Ing'],
#     [83, 90, 'Ing'],
#     [92, 101, 'Ing'],
#     [104, 116, 'Ing'],
#     [121, 125, 'Ing']]}],
#  ['Pizza Peperoni (mild) [Normal, Ø 30cm] ',
#   {'entities': [[0, 5, 'Ing'], [6, 14, 'Ing']]}],
#  ['Peppers (6 Stück) mit Jalapeno-Cream-Cheese-Füllung',
#   {'entities': [[0, 7, 'Ing'], [22, 30, 'Ing'], [31, 43, 'Ing']]}],
#  ['Gefüllte Pizzabrötchen mit Salami ',
#   {'entities': [[9, 22, 'Ing'], [27, 33, 'Ing']]}],
#  ['10 gefüllte Pizzabrötchen mit Salami ',
#   {'entities': [[12, 25, 'Ing'], [30, 36, 'Ing']]}],
#  ['6 gefüllte Pizzabrötchen mit Salami ',
#   {'entities': [[11, 24, 'Ing'], [29, 35, 'Ing']]}],
#  ['6 gefüllte Pizzabrötchen mit Salami',
#   {'entities': [[11, 24, 'Ing'], [29, 35, 'Ing']]}],
#  ['8 gefüllte Pizzabrötchen mit Salami ',
#   {'entities': [[11, 24, 'Ing'], [29, 35, 'Ing']]}],
#  ['Gefüllte Pizzabrötchen mit Salami',
#   {'entities': [[9, 22, 'Ing'], [27, 33, 'Ing']]}],
#  ['Gefüllte Pizzabrötchen mit Salami 4,5',
#   {'entities': [[9, 22, 'Ing'], [27, 33, 'Ing']]}],
#  ['Schnitzel Palermo paniert mit Spinat, Knoblauch, Tomaten - Sahnesauce und Käse überbacken',
#   {'entities': [[0, 9, 'Ing'],
#     [30, 36, 'Ing'],
#     [38, 47, 'Ing'],
#     [49, 56, 'Ing'],
#     [59, 69, 'Ing'],
#     [74, 78, 'Ing']]}],
#  ['Suki-Yaki Rindfleisch mit Glasnudeln und Gemüse',
#   {'entities': [[10, 21, 'Ing'], [26, 36, 'Ing']]}],
#  ['Suki Yaki Rindfleisch mit Glasnudeln und Gemüse',
#   {'entities': [[10, 21, 'Ing'], [26, 36, 'Ing']]}],
#  ['Suki Yaki-Rindfleisch mit Glasnudeln und Gemüse',
#   {'entities': [[10, 21, 'Ing'], [26, 36, 'Ing']]}],
#  ['Pizza Tomatenscheiben, Mozzarella und Oliven [60cm x 40cm] ',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 21, 'Ing'],
#     [23, 33, 'Ing'],
#     [38, 44, 'Ing']]}],
#  ['Broccoli Suppe ', {'entities': [[0, 8, 'Ing']]}],
#  ['Broccoli-Suppe ', {'entities': [[0, 8, 'Ing']]}],
#  ['Broccoli- Suppe ', {'entities': [[0, 8, 'Ing']]}],
#  ['Pizza Frutti di Mare [Family, 45cm x 32cm] mit Meeresfrüchten und Knoblauch',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 20, 'Ing'],
#     [47, 61, 'Ing'],
#     [66, 75, 'Ing']]}],
#  ['Pizza Frutti di Mare [Family, 48cm x 32cm] mit Meeresfrüchten und Knoblauch',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 20, 'Ing'],
#     [47, 61, 'Ing'],
#     [66, 75, 'Ing']]}],
#  ['Pizza Frutti di Mare [Family, 40cm x 32cm] mit Meeresfrüchten und Knoblauch',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 20, 'Ing'],
#     [47, 61, 'Ing'],
#     [66, 75, 'Ing']]}],
#  ['Pizza mit vier Käsesorten ',
#   {'entities': [[0, 5, 'Ing'], [10, 25, 'Ing']]}],
#  ['Malzbier 0,5l ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier 0,50l ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier 0,33l ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier 0,7l ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier 0.5l ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier 0,5 l ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier 0,33 l ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier 0,3l ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier 0.33 l', {'entities': [[0, 8, 'Ing']]}],
#  ['0,5l Malzbier ', {'entities': [[5, 13, 'Ing']]}],
#  ['Malzbier ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier 0,5 l', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier, 0,5l ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier 0,5 ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier 0.33 L ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier 0,33 l\t ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier  0,33l ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier 0,33 l', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier 0,3 l', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier 0.3 l', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier 0.33l ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier 0,2l ', {'entities': [[0, 8, 'Ing']]}],
#  ['0,33l Malzbier ', {'entities': [[6, 14, 'Ing']]}],
#  ['Malzbier 1,0l ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier 1l ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier 0,3 l ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier  0,5 l', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier, 0.5l ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier, 1.0l ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier - 1.0l ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier, 0,5 l ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier 0,33 l 0,33 l ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier 0.5 l', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier, 0,33L ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier 0,35l ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier 0,33 ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier 1,0 l ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier 0,50 l ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier (0,5 l) ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier 0,7 l ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier, 0,33 l ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier, 0,2l ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier (0,33 l) ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier 0,22l ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier ( 0,5 l) ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier - 0.33l ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier 0,2 l ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier 0,25l ', {'entities': [[0, 8, 'Ing']]}],
#  ['Malzbier, 0,4l ', {'entities': [[0, 8, 'Ing']]}],
#  ['317. Malzbier, 0,33l ', {'entities': [[5, 13, 'Ing']]}],
#  ['Nigiri Unagi mit gebratenem Süßwasseraal',
#   {'entities': [[0, 6, 'Ing'], [7, 12, 'Ing'], [28, 40, 'Ing']]}],
#  ['Pasta Mista Bolognese Tortellini, Spaghetti und Rigatoni in Bolognese-Sahnesauce und Käse überbacken',
#   {'entities': [[0, 5, 'Ing'],
#     [12, 21, 'Ing'],
#     [22, 32, 'Ing'],
#     [34, 43, 'Ing'],
#     [48, 56, 'Ing'],
#     [60, 69, 'Ing'],
#     [70, 80, 'Ing'],
#     [85, 89, 'Ing']]}],
#  ['Salat Caprese Tomaten, Mozzarella, Basilikum und Mozzarella',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 13, 'Ing'],
#     [14, 21, 'Ing'],
#     [23, 33, 'Ing'],
#     [35, 44, 'Ing'],
#     [49, 59, 'Ing']]}],
#  ['Cozze al Forno (scharf) Miesmuscheln mit Kapern, Oliven und Peperoni',
#   {'entities': [[24, 36, 'Ing'],
#     [41, 47, 'Ing'],
#     [49, 55, 'Ing'],
#     [60, 68, 'Ing']]}],
#  ['Salat Caprese mit frischen Tomaten, Mozzarella, Basilikum und Pizzabrot',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 13, 'Ing'],
#     [27, 34, 'Ing'],
#     [36, 46, 'Ing'],
#     [48, 57, 'Ing'],
#     [62, 71, 'Ing']]}],
#  ['Tagliatelle Primavera Bandnudeln mit Tomatensauce, Erbsen, Schinken und Zwiebeln',
#   {'entities': [[0, 11, 'Ing'],
#     [22, 32, 'Ing'],
#     [37, 49, 'Ing'],
#     [51, 57, 'Ing'],
#     [59, 67, 'Ing'],
#     [72, 80, 'Ing']]}],
#  ['Mutton Vindalu (sehr scharf) ', {'entities': [[0, 6, 'Ing']]}],
#  ['Enchiladas De Avocado y Espinacas mit Avocado und Spinat',
#   {'entities': [[0, 10, 'Ing'],
#     [14, 21, 'Ing'],
#     [24, 33, 'Ing'],
#     [38, 45, 'Ing'],
#     [50, 56, 'Ing']]}],
#  ['Pizza Salami [Party, 40cm x 60cm] mit Salami',
#   {'entities': [[0, 5, 'Ing'], [6, 12, 'Ing'], [38, 44, 'Ing']]}],
#  ['Pizza Salami [Party, 40 x 60cm] mit Salami',
#   {'entities': [[0, 5, 'Ing'], [6, 12, 'Ing'], [36, 42, 'Ing']]}],
#  ['Pizza Salami [Party, Ø 60cm] mit Salami',
#   {'entities': [[0, 5, 'Ing'], [6, 12, 'Ing'], [33, 39, 'Ing']]}],
#  ['Pizza Salami [Party 60cm] mit Salami',
#   {'entities': [[0, 5, 'Ing'], [6, 12, 'Ing'], [30, 36, 'Ing']]}],
#  ['Pizza Salami [Party 40cm x 60cm] mit Salami',
#   {'entities': [[0, 5, 'Ing'], [6, 12, 'Ing'], [37, 43, 'Ing']]}],
#  ['Pizza Salami [Party, 42cm x 60cm] mit Salami',
#   {'entities': [[0, 5, 'Ing'], [6, 12, 'Ing'], [38, 44, 'Ing']]}],
#  ['Insalata di Mare [Klein] gemischter Salat mit gebratenen Garnelen',
#   {'entities': [[0, 8, 'Ing'], [25, 41, 'Ing'], [57, 65, 'Ing']]}],
#  ['Pizza Funghi [Blech, F 46 cmx33cm] mit Champignons',
#   {'entities': [[0, 5, 'Ing'], [6, 12, 'Ing'], [39, 50, 'Ing']]}],
#  ['Cannelloni mit Hackfleischfüllung, Schinken, Sahne und mit Käse überbacken',
#   {'entities': [[0, 10, 'Ing'],
#     [15, 33, 'Ing'],
#     [35, 43, 'Ing'],
#     [45, 50, 'Ing'],
#     [59, 63, 'Ing']]}],
#  ['Putenspieße mit zwei Spießen, Tzatziki, hausgemachtem Krautsalat und Kräuterbutter',
#   {'entities': [[0, 11, 'Ing'],
#     [30, 38, 'Ing'],
#     [54, 64, 'Ing'],
#     [69, 82, 'Ing']]}],
#  ['Pizza Mista [Familie, Ø 45cm] mit Formfleischvorderschinken, Salami, Thunfisch, frischen Champignons und frischer Paprika',
#   {'entities': [[0, 5, 'Ing'],
#     [34, 59, 'Ing'],
#     [61, 67, 'Ing'],
#     [69, 78, 'Ing'],
#     [89, 100, 'Ing'],
#     [114, 121, 'Ing']]}],
#  ['Schweinelende mit Champignonsauce',
#   {'entities': [[0, 13, 'Ing'], [18, 33, 'Ing']]}],
#  ['Schweinelende mit Champignonsauce ',
#   {'entities': [[0, 13, 'Ing'], [18, 33, 'Ing']]}],
#  ['Pizza Greek mit Spinat und Schafskäse',
#   {'entities': [[0, 5, 'Ing'], [16, 22, 'Ing'], [27, 37, 'Ing']]}],
#  ['Chicken Curry zartes Hühnerbrustfilet mit würziger Currysauce',
#   {'entities': [[0, 7, 'Ing'],
#     [8, 13, 'Ing'],
#     [21, 37, 'Ing'],
#     [51, 61, 'Ing']]}],
#  ['Pasta Themesen (pikant) mit Thunfisch, Oliven, Champignons und Tomaten-Sahnesauce, überbacken',
#   {'entities': [[0, 5, 'Ing'],
#     [28, 37, 'Ing'],
#     [39, 45, 'Ing'],
#     [47, 58, 'Ing'],
#     [63, 70, 'Ing'],
#     [71, 81, 'Ing']]}],
#  ["Pizza Rock'n Roll mit Rindfleisch, Mais, Hähnchen und Artischocken",
#   {'entities': [[0, 5, 'Ing'],
#     [22, 33, 'Ing'],
#     [35, 39, 'Ing'],
#     [41, 49, 'Ing'],
#     [54, 66, 'Ing']]}],
#  ["Pizza Rock'n'Roll mit Rindfleisch, Mais, Hähnchen und Artischocken",
#   {'entities': [[0, 5, 'Ing'],
#     [22, 33, 'Ing'],
#     [35, 39, 'Ing'],
#     [41, 49, 'Ing'],
#     [54, 66, 'Ing']]}],
#  ['Pizza Angello (pikant) mit Peperoniwurst, Sardellen und Oliven',
#   {'entities': [[0, 5, 'Ing'],
#     [27, 40, 'Ing'],
#     [42, 51, 'Ing'],
#     [56, 62, 'Ing']]}],
#  ['Spaghetti Napoli [klein] mit Tomatensauce',
#   {'entities': [[0, 9, 'Ing'], [10, 16, 'Ing'], [29, 41, 'Ing']]}],
#  ['Spaghetti Napoli, klein mit Tomatensauce',
#   {'entities': [[0, 9, 'Ing'], [10, 16, 'Ing'], [28, 40, 'Ing']]}],
#  ['Spaghetti Napoli (klein) mit Tomatensauce',
#   {'entities': [[0, 9, 'Ing'], [10, 16, 'Ing'], [29, 41, 'Ing']]}],
#  ['Japanischer Sake 0,7l ', {'entities': [[12, 16, 'Ing']]}],
#  ['Japanischer Sake 0,3 l ', {'entities': [[12, 16, 'Ing']]}],
#  ['Japanischer Sake 300ml ', {'entities': [[12, 16, 'Ing']]}],
#  ['Japanischer Sake 0,75 l ', {'entities': [[12, 16, 'Ing']]}],
#  ['Pizza Funghi [Ø 24cm] mit frischen Champignons',
#   {'entities': [[0, 5, 'Ing'], [6, 12, 'Ing'], [35, 46, 'Ing']]}],
#  ['Pizza Funghi [S, Ø 24cm] mit frischen Champignons',
#   {'entities': [[0, 5, 'Ing'], [6, 12, 'Ing'], [38, 49, 'Ing']]}],
#  ['Pizza Funghi [M, Ø 24cm] mit frischen Champignons',
#   {'entities': [[0, 5, 'Ing'], [6, 12, 'Ing'], [38, 49, 'Ing']]}],
#  ['Pizza Funghi [L, Ø 24cm] mit frischen Champignons',
#   {'entities': [[0, 5, 'Ing'], [6, 12, 'Ing'], [38, 49, 'Ing']]}],
#  ['Pizza Funghi [24cm] mit frischen Champignons',
#   {'entities': [[0, 5, 'Ing'], [6, 12, 'Ing'], [33, 44, 'Ing']]}],
#  ["Penne all' Arrabiata (scharf) mit Tomaten, Chilischoten und Knoblauch",
#   {'entities': [[0, 5, 'Ing'],
#     [11, 20, 'Ing'],
#     [34, 41, 'Ing'],
#     [43, 55, 'Ing'],
#     [60, 69, 'Ing']]}],
#  ['Pizza mit Hähnchenfleisch, Champignons, Knoblauch, Zwiebeln [Klein, Ø 26cm] und Peperoni',
#   {'entities': [[0, 5, 'Ing'],
#     [10, 25, 'Ing'],
#     [27, 38, 'Ing'],
#     [40, 49, 'Ing'],
#     [51, 59, 'Ing'],
#     [80, 88, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch [Klein, Ø 27cm] ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch [klein Ø 27cm] ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizza XXXL (scharf) [Family, 33cm x 45cm] mit Salami, Schinken, Champignons, Mais, Knoblauch, Peperoni, Bohnen, Zwiebeln, Speck und extra dicken Bohnen',
#   {'entities': [[0, 5, 'Ing'],
#     [46, 52, 'Ing'],
#     [54, 62, 'Ing'],
#     [64, 75, 'Ing'],
#     [77, 81, 'Ing'],
#     [83, 92, 'Ing'],
#     [94, 102, 'Ing'],
#     [104, 110, 'Ing'],
#     [112, 120, 'Ing'],
#     [122, 127, 'Ing'],
#     [145, 151, 'Ing']]}],
#  ['Pizza Margharita [Groß, Ø 30cm] mit Tomatensauce und Käse',
#   {'entities': [[0, 5, 'Ing'], [36, 48, 'Ing'], [53, 57, 'Ing']]}],
#  ['Pizza Mozzarella mit Tomatenscheiben, Mozzarella und geschrotetem Pfeffer',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 16, 'Ing'],
#     [21, 36, 'Ing'],
#     [38, 48, 'Ing'],
#     [66, 73, 'Ing']]}],
#  ['Nigiri Tabico mit Flugfischrogen',
#   {'entities': [[0, 6, 'Ing'], [18, 32, 'Ing']]}],
#  ['Rumpsteak al Pepe Verde argentinisches Rumpsteak mit grüner Pfeffersauce',
#   {'entities': [[0, 9, 'Ing'], [39, 48, 'Ing'], [60, 72, 'Ing']]}],
#  ['Pizza New York [Party, 40cm x 60cm] mit Lachs, Parmesan und Knoblauch',
#   {'entities': [[0, 5, 'Ing'],
#     [40, 45, 'Ing'],
#     [47, 55, 'Ing'],
#     [60, 69, 'Ing']]}],
#  ['Fusili Napoli mit Tomatensauce',
#   {'entities': [[0, 6, 'Ing'], [7, 13, 'Ing'], [18, 30, 'Ing']]}],
#  ['Maccheroni Al Tonno mit Thunfisch, Zwiebeln, Erbsen, Knoblauch und Tomatensauce',
#   {'entities': [[0, 10, 'Ing'],
#     [14, 19, 'Ing'],
#     [24, 33, 'Ing'],
#     [35, 43, 'Ing'],
#     [45, 51, 'Ing'],
#     [53, 62, 'Ing'],
#     [67, 79, 'Ing']]}],
#  ['Hähnchenfleisch (Pilze) mit Pilzen, Paprika und Spargel',
#   {'entities': [[0, 15, 'Ing'],
#     [17, 22, 'Ing'],
#     [28, 34, 'Ing'],
#     [36, 43, 'Ing'],
#     [48, 55, 'Ing']]}],
#  ['Pizza Gyros 3 [Mini, Ø 20cm] mit Gyros, Zwiebeln, frischen Tomaten und Sauce Hollandaise',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 11, 'Ing'],
#     [33, 38, 'Ing'],
#     [40, 48, 'Ing'],
#     [59, 66, 'Ing'],
#     [71, 88, 'Ing']]}],
#  ['Pizza O Sole Mio [Groß, ca. Ø 32cm] mit Schinken, Spargel, Peperoni und Ei',
#   {'entities': [[0, 5, 'Ing'],
#     [40, 48, 'Ing'],
#     [50, 57, 'Ing'],
#     [59, 67, 'Ing'],
#     [72, 74, 'Ing']]}],
#  ['Cali Menü <br>• 4 California Inside-Out<br>• 6 Tekka Maki<br>• 6 Sake Maki',
#   {'entities': [[53, 57, 'Ing'], [65, 69, 'Ing'], [70, 74, 'Ing']]}],
#  ['Cali Menü • 4 California Inside-Out• 6 Tekka Maki• 6 Sake Maki',
#   {'entities': [[45, 49, 'Ing'], [53, 57, 'Ing'], [58, 62, 'Ing']]}],
#  ['Bionade Litchi 0,3l ', {'entities': [[0, 7, 'Brand'], [8, 14, 'Flavor']]}],
#  ['Bionade Litchi 0,33l ', {'entities': [[0, 7, 'Brand'], [8, 14, 'Flavor']]}],
#  ['Bionade Litchi, 0,33l ',
#   {'entities': [[0, 7, 'Brand'], [8, 14, 'Flavor']]}],
#  ['Bionade Litchi 0,33 l', {'entities': [[0, 7, 'Brand'], [8, 14, 'Flavor']]}],
#  ['Bionade litchi ', {'entities': [[0, 7, 'Brand'], [8, 14, 'Flavor']]}],
#  ['Bionade Litchi 0,5 l ', {'entities': [[0, 7, 'Brand'], [8, 14, 'Flavor']]}],
#  ['Bionade Litchi 0,33 l ',
#   {'entities': [[0, 7, 'Brand'], [8, 14, 'Flavor']]}],
#  ['Bionade Litchi 0,2l ', {'entities': [[0, 7, 'Brand'], [8, 14, 'Flavor']]}],
#  ['Calamaris Speciale (paniert) frittierte Tintenfischringe mit Kapern, Oliven, Knoblauch und Tomatensauce, Reis und Salat',
#   {'entities': [[0, 9, 'Ing'],
#     [40, 56, 'Ing'],
#     [61, 67, 'Ing'],
#     [69, 75, 'Ing'],
#     [77, 86, 'Ing'],
#     [91, 103, 'Ing'],
#     [105, 109, 'Ing'],
#     [114, 119, 'Ing']]}],
#  ['Pizza Hawaii mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [17, 25, 'Ing'],
#     [30, 36, 'Ing']]}],
#  ['Pizza Hawaii Ø 30cm mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [24, 32, 'Ing'],
#     [37, 43, 'Ing']]}],
#  ['Pizza Hawaii 1 mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [19, 27, 'Ing'],
#     [32, 38, 'Ing']]}],
#  ['Pizza Hawaii [32 cm ⌀] mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [27, 35, 'Ing'],
#     [40, 46, 'Ing']]}],
#  ['Pizza Hawaii I mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [19, 27, 'Ing'],
#     [32, 38, 'Ing']]}],
#  ['Pizza Hawaii mit Schinken\xa0und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [17, 25, 'Ing'],
#     [30, 36, 'Ing']]}],
#  ['Pizza Hawaii\xa0 mit Schinken und Ananas\xa0',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [18, 26, 'Ing'],
#     [31, 37, 'Ing']]}],
#  ['Pizza Hawaii 2 mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [19, 27, 'Ing'],
#     [32, 38, 'Ing']]}],
#  ['Pizza Hawaii mit Schinken und Ananas ',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [17, 25, 'Ing'],
#     [30, 36, 'Ing']]}],
#  ['Pizza Hawaii [M] mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [21, 29, 'Ing'],
#     [34, 40, 'Ing']]}],
#  ['Pizza Hawaii 26cm mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [22, 30, 'Ing'],
#     [35, 41, 'Ing']]}],
#  ['Pizza Hawaii, Ø 26cm mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [25, 33, 'Ing'],
#     [38, 44, 'Ing']]}],
#  ['Pizza Hawaii [L] mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [21, 29, 'Ing'],
#     [34, 40, 'Ing']]}],
#  ['Pizza Hawaii, Ø 32cm mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [25, 33, 'Ing'],
#     [38, 44, 'Ing']]}],
#  ['Pizza Hawaii\xa0 mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [18, 26, 'Ing'],
#     [31, 37, 'Ing']]}],
#  ['Pizza Hawaii, Ø 36cm mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [25, 33, 'Ing'],
#     [38, 44, 'Ing']]}],
#  ['Pizza Hawaii  mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [18, 26, 'Ing'],
#     [31, 37, 'Ing']]}],
#  ['Pizza Hawaii mit Schinken und Ananas.',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [17, 25, 'Ing'],
#     [30, 36, 'Ing']]}],
#  ['Pizza Hawaii [S] mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [21, 29, 'Ing'],
#     [34, 40, 'Ing']]}],
#  ['Pizza Hawaii, Ø 22cm mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [25, 33, 'Ing'],
#     [38, 44, 'Ing']]}],
#  ['Pizza Hawaii mit Schinken, und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [17, 25, 'Ing'],
#     [31, 37, 'Ing']]}],
#  ['Pizza Hawaii 25cm mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [22, 30, 'Ing'],
#     [35, 41, 'Ing']]}],
#  ['Pizza Hawaii 32cm mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [22, 30, 'Ing'],
#     [35, 41, 'Ing']]}],
#  ['Pizza Hawaii 20 cm mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [23, 31, 'Ing'],
#     [36, 42, 'Ing']]}],
#  ['Pizza Hawaii Ø28cm mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [23, 31, 'Ing'],
#     [36, 42, 'Ing']]}],
#  ['Pizza 16 Hawaii mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [9, 15, 'Ing'],
#     [20, 28, 'Ing'],
#     [33, 39, 'Ing']]}],
#  ['Pizza Hawaii 30 cm mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [23, 31, 'Ing'],
#     [36, 42, 'Ing']]}],
#  ['Pizza Hawaii 26 cm mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [23, 31, 'Ing'],
#     [36, 42, 'Ing']]}],
#  ['Pizza "Hawaii" mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [7, 13, 'Ing'],
#     [19, 27, 'Ing'],
#     [32, 38, 'Ing']]}],
#  ['Pizza Hawaii, Ø 40cm x 60cm mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [32, 40, 'Ing'],
#     [45, 51, 'Ing']]}],
#  ['Pizza Hawaii Ø 26cm mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [24, 32, 'Ing'],
#     [37, 43, 'Ing']]}],
#  ['Pizza Hawaii Ø 28cm mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [24, 32, 'Ing'],
#     [37, 43, 'Ing']]}],
#  ['Pizza Hawaii [Ø 28] mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [24, 32, 'Ing'],
#     [37, 43, 'Ing']]}],
#  ['Pizza Hawaii, Ø 40cm mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [25, 33, 'Ing'],
#     [38, 44, 'Ing']]}],
#  ['Pizza\xa0Hawaii mit\xa0Schinken\xa0und\xa0Ananas\xa0\xa0',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [17, 25, 'Ing'],
#     [30, 36, 'Ing']]}],
#  ['Pizza Hawaii Ø29cm mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [23, 31, 'Ing'],
#     [36, 42, 'Ing']]}],
#  ['Pizza Hawaii Ø40 cm mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [24, 32, 'Ing'],
#     [37, 43, 'Ing']]}],
#  ['Pizza Hawaii, 26cm mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [23, 31, 'Ing'],
#     [36, 42, 'Ing']]}],
#  ['Pizza Hawaii, Ø26cm mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [24, 32, 'Ing'],
#     [37, 43, 'Ing']]}],
#  ['Pizza Hawaii [26 cm ⌀] mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [27, 35, 'Ing'],
#     [40, 46, 'Ing']]}],
#  ['Pizza Hawaii [Ø 32] mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [24, 32, 'Ing'],
#     [37, 43, 'Ing']]}],
#  ['Pizza Hawaii, Ø 28cm  mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [26, 34, 'Ing'],
#     [39, 45, 'Ing']]}],
#  ['Pizza Hawaii, M mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [20, 28, 'Ing'],
#     [33, 39, 'Ing']]}],
#  ['Pizza Hawaii [Ø 36] mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [24, 32, 'Ing'],
#     [37, 43, 'Ing']]}],
#  ['Pizza Hawaii mit Schinken und Ananas (A)',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [17, 25, 'Ing'],
#     [30, 36, 'Ing']]}],
#  ['Pizza Hawaii, Ø 29cm mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [25, 33, 'Ing'],
#     [38, 44, 'Ing']]}],
#  ['Pizza Hawaii, Ø 50cm mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [25, 33, 'Ing'],
#     [38, 44, 'Ing']]}],
#  ['Pizza Hawaii, Ø 30cm mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [25, 33, 'Ing'],
#     [38, 44, 'Ing']]}],
#  ['Pizza Hawaii Ø 26cm <br> mit Schinken und Ananas',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [29, 37, 'Ing'],
#     [42, 48, 'Ing']]}],
#  ['7 Pizza Hawaii mit Schinken und Ananas',
#   {'entities': [[2, 7, 'Ing'],
#     [8, 14, 'Ing'],
#     [19, 27, 'Ing'],
#     [32, 38, 'Ing']]}],
#  ['Schnitzel paniert mit Pommes Frites und Salat',
#   {'entities': [[0, 9, 'Ing'], [22, 35, 'Ing'], [40, 45, 'Ing']]}],
#  ['Schnitzel paniert<br>mit Pommes frites und Salat',
#   {'entities': [[0, 9, 'Ing'], [25, 38, 'Ing'], [43, 48, 'Ing']]}],
#  ['Schnitzel, paniert mit Pommes frites und Salat',
#   {'entities': [[0, 9, 'Ing'], [23, 36, 'Ing'], [41, 46, 'Ing']]}],
#  ['Schnitzel paniert, mit Pommes frites und Salat',
#   {'entities': [[0, 9, 'Ing'], [23, 36, 'Ing'], [41, 46, 'Ing']]}],
#  ['Schnitzel (paniert) mit Pommes frites und Salat',
#   {'entities': [[0, 9, 'Ing'], [24, 37, 'Ing'], [42, 47, 'Ing']]}],
#  ['Schnitzel (paniert) mit Pommes frites und Salat ',
#   {'entities': [[0, 9, 'Ing'], [24, 37, 'Ing'], [42, 47, 'Ing']]}],
#  ['Schnitzel paniert mit Pommes frites und Salat ',
#   {'entities': [[0, 9, 'Ing'], [22, 35, 'Ing'], [40, 45, 'Ing']]}],
#  ['Schweinefleisch Chop Suey mit verschiedenem Gemüse',
#   {'entities': [[0, 15, 'Ing'], [16, 25, 'Ing']]}],
#  ['Schweinefleisch-Chop Suey mit verschiedenem Gemüse',
#   {'entities': [[0, 15, 'Ing'], [16, 25, 'Ing']]}],
#  ['Schweinefleisch Chop-Suey mit verschiedenem Gemüse',
#   {'entities': [[0, 15, 'Ing'], [16, 25, 'Ing']]}],
#  ['Schweinefleisch - Chop Suey mit verschiedenem Gemüse',
#   {'entities': [[0, 15, 'Ing'], [18, 27, 'Ing']]}],
#  ['M7 Schweinefleisch Chop Suey mit verschiedenem Gemüse',
#   {'entities': [[3, 18, 'Ing'], [19, 28, 'Ing']]}],
#  ['Schweinefleisch (Chop Suey) mit verschiedenem Gemüse',
#   {'entities': [[0, 15, 'Ing'], [17, 26, 'Ing']]}],
#  ['Schweinefleisch „Chop Suey“ mit verschiedenem Gemüse',
#   {'entities': [[0, 15, 'Ing'], [17, 26, 'Ing']]}],
#  ["Schweinefleisch 'Chop Suey' mit verschiedenem Gemüse",
#   {'entities': [[0, 15, 'Ing'], [17, 26, 'Ing']]}],
#  ['Schweinefleisch Chop - Suey mit verschiedenem Gemüse',
#   {'entities': [[0, 15, 'Ing'], [16, 27, 'Ing']]}],
#  ['Schweinefleisch Chop- Suey mit verschiedenem Gemüse',
#   {'entities': [[0, 15, 'Ing'], [16, 26, 'Ing']]}],
#  ['Schweinefleisch Chop Suey mit verschiedenem Gemüse ',
#   {'entities': [[0, 15, 'Ing'], [16, 25, 'Ing']]}],
#  ['Schweinefleisch Chop-Suey mit verschiedenem Gemüse ',
#   {'entities': [[0, 15, 'Ing'], [16, 25, 'Ing']]}],
#  ['Maccheroni al Tonno mit Thunfisch und Tomatensauce',
#   {'entities': [[0, 10, 'Ing'],
#     [14, 19, 'Ing'],
#     [24, 33, 'Ing'],
#     [38, 50, 'Ing']]}],
#  ['Pizza Santo [Mittel, Ø 26cm] mit Tomatensauce, scharfer italienischer Salami, pikanten Oliven und Zwiebeln',
#   {'entities': [[0, 5, 'Ing'],
#     [33, 45, 'Ing'],
#     [70, 76, 'Ing'],
#     [87, 93, 'Ing'],
#     [98, 106, 'Ing']]}],
#  ['Pizza Shrimps [Normal, Ø 28cm] mit Krabben und Knoblauch',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 13, 'Ing'],
#     [35, 42, 'Ing'],
#     [47, 56, 'Ing']]}],
#  ['Pizza Bella Italia [Ø 30cm] mit Artischocken, Ei, Peperoniwurst, Pilzen und Schinken',
#   {'entities': [[0, 5, 'Ing'],
#     [32, 44, 'Ing'],
#     [46, 48, 'Ing'],
#     [50, 63, 'Ing'],
#     [65, 71, 'Ing'],
#     [76, 84, 'Ing']]}],
#  ['Pizza Norma [1 Person, Ø 29cm] mit Auberginen und Parmesankäse',
#   {'entities': [[0, 5, 'Ing'], [35, 45, 'Ing'], [50, 62, 'Ing']]}],
#  ['Pizza Bolognese [Ø 30cm] mit Schinken, Salami, Champignons und Sauce Bolognese',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 15, 'Ing'],
#     [29, 37, 'Ing'],
#     [39, 45, 'Ing'],
#     [47, 58, 'Ing'],
#     [69, 78, 'Ing']]}],
#  ['Pizza Muscheln [Familie, 46cm x 33cm] mit Thunfisch und Krabben',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 14, 'Ing'],
#     [42, 51, 'Ing'],
#     [56, 63, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch', {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch ', {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot\xa0 mit Knoblauch',
#   {'entities': [[0, 9, 'Ing'], [15, 24, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch 30cm ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch [M] ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch, Ø 30cm ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot 28cm mit Knoblauch',
#   {'entities': [[0, 9, 'Ing'], [19, 28, 'Ing']]}],
#  ['Pizzabrot, Ø 28cm mit Knoblauch',
#   {'entities': [[0, 9, 'Ing'], [22, 31, 'Ing']]}],
#  ['Pizzabrot Ø 28cm <br> mit Knoblauch',
#   {'entities': [[0, 9, 'Ing'], [26, 35, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch Ø 20cm ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot  mit Knoblauch', {'entities': [[0, 9, 'Ing'], [15, 24, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch, Ø 26cm ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot, Ø 30cm mit Knoblauch',
#   {'entities': [[0, 9, 'Ing'], [22, 31, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch, 24 cm ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot   mit Knoblauch', {'entities': [[0, 9, 'Ing'], [16, 25, 'Ing']]}],
#  ['Pizzabrot, Ø 26cm mit Knoblauch',
#   {'entities': [[0, 9, 'Ing'], [22, 31, 'Ing']]}],
#  ['Pizzabrot (S) mit Knoblauch',
#   {'entities': [[0, 9, 'Ing'], [18, 27, 'Ing']]}],
#  ['Pizzabrot I mit Knoblauch', {'entities': [[0, 9, 'Ing'], [16, 25, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch 26cm ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch 29cm ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot Ø 28 cm mit Knoblauch',
#   {'entities': [[0, 9, 'Ing'], [22, 31, 'Ing']]}],
#  ['Pizzabrot, Ø 32cm mit Knoblauch',
#   {'entities': [[0, 9, 'Ing'], [22, 31, 'Ing']]}],
#  ['Pizzabrot (mit Knoblauch) ',
#   {'entities': [[0, 9, 'Ing'], [15, 24, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch, Ø 36 cm ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot Ø 28cm mit Knoblauch',
#   {'entities': [[0, 9, 'Ing'], [21, 30, 'Ing']]}],
#  ['Pizzabrot, Ø 28cm mit Knoblauch ',
#   {'entities': [[0, 9, 'Ing'], [22, 31, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch, 22 cm ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch, Ø 28cm ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch Ø 30cm ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch, Ø 32cm ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch Ø 28cm ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch, 24cm ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot, 30cm mit Knoblauch',
#   {'entities': [[0, 9, 'Ing'], [20, 29, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch, 32cm x 45cm ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot 28cm mit Knoblauch ',
#   {'entities': [[0, 9, 'Ing'], [19, 28, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch,Ø 22cm ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot 32cm mit Knoblauch',
#   {'entities': [[0, 9, 'Ing'], [19, 28, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch [S] ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot, 28 cm mit Knoblauch',
#   {'entities': [[0, 9, 'Ing'], [21, 30, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch 32cm ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot (M) mit Knoblauch',
#   {'entities': [[0, 9, 'Ing'], [18, 27, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch 27cm ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot Ø 38cm mit Knoblauch',
#   {'entities': [[0, 9, 'Ing'], [21, 30, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch, 28cm ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot, 30 cm mit Knoblauch',
#   {'entities': [[0, 9, 'Ing'], [21, 30, 'Ing']]}],
#  ['Pizzabrot, Ø 33cm mit Knoblauch',
#   {'entities': [[0, 9, 'Ing'], [22, 31, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch L, Ø 33cm ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch [Ø 30] ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch Ø30cm ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch, Ø26cm ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch, 32 cm ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch, 22cm ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot 2 mit Knoblauch', {'entities': [[0, 9, 'Ing'], [16, 25, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch, 30 cm ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Pizzabrot mit Knoblauch, 26 cm ',
#   {'entities': [[0, 9, 'Ing'], [14, 23, 'Ing']]}],
#  ['Der Avocado Burger mit hausgemachter Avocado-Djionnaise, Meerrettichsauce, Rucola, Zwiebeln und Sprossen',
#   {'entities': [[4, 11, 'Ing'],
#     [12, 18, 'Ing'],
#     [37, 44, 'Ing'],
#     [57, 73, 'Ing'],
#     [75, 81, 'Ing'],
#     [83, 91, 'Ing'],
#     [96, 104, 'Ing']]}],
#  ['Pizza Cipolla [Klein, Ø 26cm] mit Zwiebeln',
#   {'entities': [[0, 5, 'Ing'], [6, 13, 'Ing'], [34, 42, 'Ing']]}],
#  ['Pizza Cipolla [klein 26cm] mit Zwiebeln',
#   {'entities': [[0, 5, 'Ing'], [6, 13, 'Ing'], [31, 39, 'Ing']]}],
#  ['Pizza Cipolla [Klein Ø 26cm] mit Zwiebeln',
#   {'entities': [[0, 5, 'Ing'], [6, 13, 'Ing'], [33, 41, 'Ing']]}],
#  ['Pizza Cipolla [klein, 26cm] mit Zwiebeln',
#   {'entities': [[0, 5, 'Ing'], [6, 13, 'Ing'], [32, 40, 'Ing']]}],
#  ['Pizza Cipolla [klein 26cm.] mit Zwiebeln',
#   {'entities': [[0, 5, 'Ing'], [6, 13, 'Ing'], [32, 40, 'Ing']]}],
#  ["Ali's Pizza [klein, Ø 26cm] mit Spinat, Thunfisch, Knoblauchwurst, Schafskäse",
#   {'entities': [[6, 11, 'Ing'],
#     [32, 38, 'Ing'],
#     [40, 49, 'Ing'],
#     [51, 65, 'Ing'],
#     [67, 77, 'Ing']]}],
#  ['Amerikanische Pizza Texas [XXL] mit Vorderschinken, Salami, Champignons und Peperoni',
#   {'entities': [[14, 19, 'Ing'],
#     [36, 50, 'Ing'],
#     [52, 58, 'Ing'],
#     [60, 71, 'Ing'],
#     [76, 84, 'Ing']]}],
#  ['Scaloppina Gorgonzola (paniert) paniertes Schweineschnitzel mit Gorgonzolasauce, Pommes frites und gemischtem Salat',
#   {'entities': [[11, 21, 'Ing'],
#     [42, 59, 'Ing'],
#     [64, 79, 'Ing'],
#     [81, 94, 'Ing'],
#     [110, 115, 'Ing']]}],
#  ['Bolognese-Schnitzel mit Hackfleischsauce und mit Käse überbacken',
#   {'entities': [[0, 9, 'Ing'],
#     [10, 19, 'Ing'],
#     [24, 40, 'Ing'],
#     [49, 53, 'Ing']]}],
#  ['Bolognese Schnitzel mit Hackfleischsauce und mit Käse überbacken',
#   {'entities': [[0, 9, 'Ing'],
#     [10, 19, 'Ing'],
#     [24, 40, 'Ing'],
#     [49, 53, 'Ing']]}],
#  ['2 Bolognese Schnitzel mit Hackfleischsauce und mit Käse überbacken',
#   {'entities': [[2, 11, 'Ing'],
#     [12, 21, 'Ing'],
#     [26, 42, 'Ing'],
#     [51, 55, 'Ing']]}],
#  ['Pizza Salami [Party, 40cm x 60cm] mit Tomaten, Salami und Käse',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
# ...
#  ['Mezzo-Mix 1,00l ', {'entities': []}],
#  ['Mezzo Mix 0,5 l  0,5 l ', {'entities': []}],
#  ['Mezzo Mix, 1.5l ', {'entities': []}],
#  ['Mezzo Mix, 0,33 L ', {'entities': []}],
#  ['Mezzo-Mix 0,2l ', {'entities': []}],
#  ['Mezzo - Mix 1L ', {'entities': []}],
#  ['Mezzo Mix 0,40 l ', {'entities': []}],
#  ['Mezzo Mix  1l ', {'entities': []}],
#  ['Mezzo-Mix [0,5 l] ', {'entities': []}],
#  ['Mezzo Mix - 0,5l ', {'entities': []}],
#  ['Mezzo-Mix  0,33 l ', {'entities': []}],
#  ['Mezzo-Mix, 1,0 l ', {'entities': []}],
#  ['Mezzo Mix 1 l  1,0 l', {'entities': []}],
#  ['0,5l Mezzo Mix ', {'entities': []}],
#  ['Mezzo Mix (1,0 l) ', {'entities': []}],
#  ['Mezzo Mix 0.33 l', {'entities': []}],
#  ['Mezzo-Mix 0,1l ', {'entities': []}],
#  ['Mezzo Mix  0,33l ', {'entities': []}],
#  ['Mezzo Mix  0,5 l', {'entities': []}],
#  ['Mezzo Mix 1 l + 0,15 €', {'entities': []}],
#  ['Mezzo Mix 24 x 0,33l ', {'entities': []}],
#  ['Mezzo Mix 0.1l ', {'entities': []}],
#  ['Mezzo Mix 0,50 l ', {'entities': []}],
#  ['Mezzo Mix 0,50l ', {'entities': []}],
#  ['Mezzo-Mix 1.5L ', {'entities': []}],
#  ['Mezzo Mix, 1,5l ', {'entities': []}],
#  ['Mezzo Mix, 0,25l ', {'entities': []}],
#  ['Mezzo Mix0,33l ', {'entities': []}],
#  ['Mezzo Mix, 0,3L ', {'entities': []}],
#  ['Mezzo Mix, 24 x 0,33 l ', {'entities': []}],
#  ['Mezzo Mix ^,0l ', {'entities': []}],
#  ['Mezzo-Mix 1,25l ', {'entities': []}],
#  ['Mezzo Mix 1,25 L ', {'entities': []}],
#  ['G5 - Mezzo Mix 0,5l ', {'entities': []}],
#  ['Mezzo- Mix 1,0 l', {'entities': []}],
#  ['Mezzo Mix 2,0l ', {'entities': []}],
#  ['1,5l Mezzo Mix ', {'entities': []}],
#  ['Mezzo Mix, 1,25l ', {'entities': []}],
#  ['Mezzo- Mix 1,0l ', {'entities': []}],
#  ['Mezzo Mix 12 x 0,5l ', {'entities': []}],
#  ['Mezzo Mix 1 L 1,80', {'entities': []}],
#  ['Mezzo Mix 1,5 l', {'entities': []}],
#  ['Mezzo Mix 24 x 0,2l ', {'entities': []}],
#  ['Mezzo Mix 0,7 L ', {'entities': []}],
#  ['Mezzo Mix  1 l', {'entities': []}],
#  ['Mezzo- Mix 0,33 l ', {'entities': []}],
#  ['Mezzo Mix 0,22l ', {'entities': []}],
#  ['Mezzo-Mix [0,33 l] ', {'entities': []}],
#  ['Mezzo Mix (0,5 l) ', {'entities': []}],
#  ['Mezzo Mix 330ml ', {'entities': []}],
#  ['Mezzo Mix 12 x 1 L', {'entities': []}],
#  ['Mezzo Mix [0,25 l] ', {'entities': []}],
#  ['Mezzo-Mix (1,0 l) ', {'entities': []}],
#  ['Mezzo Mix 0,30 l ', {'entities': []}],
#  ['Mezzo- Mix ', {'entities': []}],
#  ['Mezzo Mix 1,5 l 1,5 l', {'entities': []}],
#  ['Mezzo Mix 1,0l 0,33l ', {'entities': []}],
#  ['Mezzo Mix, 1,5 L ', {'entities': []}],
#  ['Mezzo Mix 12 x 1 ', {'entities': []}],
#  ['Mezzo- Mix 1 l ', {'entities': []}],
#  ['Mezzo Mix 0,33l [1,0 l] ', {'entities': []}],
#  ['Mezzo-Mix [0,3 l] ', {'entities': []}],
#  ['Mezzo-Mix 1,00 l ', {'entities': []}],
#  ['Mezzo Mix 0,25 l ', {'entities': []}],
#  ['Mezzo Mix1,0 l ', {'entities': []}],
#  ['Mezzo mix [1,00 L] ', {'entities': []}],
#  ['Mezzo Mix 1,0 l L ', {'entities': []}],
#  ['Mezzo Mix 1,5l 1.5 l', {'entities': []}],
#  ['Mezzo-Mix [1 l] ', {'entities': []}],
#  ['Mezzo Mix - 1.0l ', {'entities': []}],
#  ['Mezzo Mix [0,4 l] ', {'entities': []}],
#  ['Mezzo Mix 0,4 l ', {'entities': []}],
#  ['Mezzo Mix 0,33l 1,50', {'entities': []}],
#  ['Mezzo-Mix 0,3 L ', {'entities': []}],
#  ['Mezzo Mix [1,25 l] ', {'entities': []}],
#  ['Mezzo Mix 1,0l 1,0l ', {'entities': []}],
#  ['Mezzo-Mix, 0,5L ', {'entities': []}],
#  ['Mezzo Mix 033l ', {'entities': []}],
#  ['Mezzo-Mix, 0,33l ', {'entities': []}],
#  ['Mezzo-Mix 0,7 l ', {'entities': []}],
#  ['Mezzo Mix, 0,5 l ', {'entities': []}],
#  ['Mezzo Mix 0.3l ', {'entities': []}],
#  ['Mezzo Mix [0,2 l] ', {'entities': []}],
#  ['Mezzo Mix, 1,0l 1,0l ', {'entities': []}],
#  ['Mezzo - Mix, 1L ', {'entities': []}],
#  ['Mezzo Mix 0,35l ', {'entities': []}],
#  ['Mezzo-Mix 0,4l ', {'entities': []}],
#  ['Mezzo-Mix 0,33 ', {'entities': []}],
#  ['Mezzo Mix 0,5l 0,5l ', {'entities': []}],
#  ['Mezzo Mix 12 x 1l ', {'entities': []}],
#  ['Mezzo-Mix 12 x 1,0l ', {'entities': []}],
#  ['Mezzo Mix (1,5 l) ', {'entities': []}],
#  ['Mezzo Mix 0,5l 0,33l ', {'entities': []}],
#  ['Mezzo- Mix 0,5l ', {'entities': []}],
#  ['Mezzo - Mix, 0,5 l ', {'entities': []}],
#  ['Mezzo Mix, 500 ml ', {'entities': []}],
#  ['Mezzo Mix t 1,0l ', {'entities': []}],
#  ['Mezzo Mix, 0,2 l ', {'entities': []}],
#  ['*Mezzo Mix, 0,33l ', {'entities': []}],
#  ['Mezzo Mix0,3l ', {'entities': []}],
#  ['Mezzo-Mix 2,0l ', {'entities': []}],
#  ['Mezzo-Mix, 0,33 l ', {'entities': []}],
#  ['Mezzo Mix ,10l ', {'entities': []}],
#  ['Mezzo Mix 20 x 0,50l ', {'entities': []}],
#  ['Mezzo-Mix 0,25l ', {'entities': []}],
#  ['Mezzo Mix 2,50', {'entities': []}],
#  ['Mezzo Mix ,0,33l ', {'entities': []}],
#  ['Mezzo Mix 1,25 ', {'entities': []}],
#  ['Mezzo Mix 2,0', {'entities': []}],
#  ['Mezzo Mix 1,30l ', {'entities': []}],
#  ['Mezzo Mix0,5l ', {'entities': []}],
#  ['Mezzo Mix 01,0L ', {'entities': []}],
#  ['Pizza Tirolese mit Käse, Tomatensauce, Speck und Tomaten',
#   {'entities': [[0, 5, 'Ing'],
#     [19, 23, 'Ing'],
#     [25, 37, 'Ing'],
#     [39, 44, 'Ing'],
#     [49, 56, 'Ing']]}],
#  ['Pizza mit Vorderschinken und Knoblauch [Normal 27cm] scharf',
#   {'entities': [[0, 5, 'Ing'], [10, 24, 'Ing'], [29, 38, 'Ing']]}],
#  ['Pizza Napolitana mit Zwiebeln, Sardellen, Oliven und Kapern',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 16, 'Ing'],
#     [21, 29, 'Ing'],
#     [31, 40, 'Ing'],
#     [42, 48, 'Ing'],
#     [53, 59, 'Ing']]}],
#  ['Rollendöner mit Salat und Soße nach Wahl', {'entities': [[16, 21, 'Ing']]}],
#  ['Murgh Shorba indische Hühnerfleischsuppe', {'entities': [[22, 40, 'Ing']]}],
#  ['Murgh-Shorba indische Hühnerfleischsuppe', {'entities': [[22, 40, 'Ing']]}],
#  ['Hähnchensalat mit Hähnchenbrustfilet, grünem Salat, Gurken und Peperoni',
#   {'entities': [[0, 13, 'Ing'],
#     [18, 36, 'Ing'],
#     [45, 50, 'Ing'],
#     [52, 58, 'Ing'],
#     [63, 71, 'Ing']]}],
#  ['Sucuk Baguette mit Sucuk, Salat, frischen Tomaten, Gurken und Käse',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 14, 'Ing'],
#     [19, 24, 'Ing'],
#     [26, 31, 'Ing'],
#     [42, 49, 'Ing'],
#     [51, 57, 'Ing'],
#     [62, 66, 'Ing']]}],
#  ['Lambrusco 0,7l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0.75l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0,75l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 1,5l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0,75 l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 1,5 l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 2l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 2,0 l', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0,75 l', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0.75 l', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 2,0l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0,75 l  ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0.7l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco  ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0,25l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 1,5 ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco - 1,5l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0,7 l', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0,7 l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0.7 l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 1,0 l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 1,55l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0,33l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco, 0,7l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0,70 l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 1,0l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0,70l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 1,50 l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0,75 ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0,5l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco, 0,2 l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco, 0.7l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 1,55 l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0,25 l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco, 0,75L ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 1,0 l', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0.75 l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco [1,5 l] ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 2,00l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 1,50l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0,75 l 0,75 l', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 2 l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco  0,7 l', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0,7 ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 1.5l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0, 25 l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco - 0,7l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 1.5 l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0,7l  ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0, 75 l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 1,25l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco, 0,7 l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco, 2L ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0.7 l', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0,70 l', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco, 1,5l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0.70l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco (2,0 l) ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0,751', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco [0,75 l] ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco\xa0\xa0 0,75 L\xa0', {'entities': [[0, 9, 'Ing']]}],
#  ['0,75l Lambrusco ', {'entities': [[6, 15, 'Ing']]}],
#  ['1,5 l Lambrusco ', {'entities': [[6, 15, 'Ing']]}],
#  ['Lambrusco 0,2l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 2.0l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0.2l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 2,0 l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco [0,7 L] ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 1,5/2l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 1.50 l ', {'entities': [[0, 9, 'Ing']]}],
#  ['1.5l Lambrusco ', {'entities': [[5, 14, 'Ing']]}],
#  ['Lambrusco  0,7l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco  0,75 l', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0,2 l', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 1,5 l', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0,33l 0,7 l', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco - 0,75l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0,7', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 1l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco, 0,75 l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco - 2,0l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0,9l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco - 1,5 l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco, 1,5 l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco (0,25) ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco1,5l ', {'entities': [[0, 10, 'Ing']]}],
#  ['Lambrusco 0,2 l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0.25l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 1,00 l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0,25l 0,25l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco, 0,75 ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco, 2 l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco, 1,0l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco [2,0 l] ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 1 L ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco [2 L] ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco, 0,25L ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 750ml ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 75 cl ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0,3l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0,33l 0,75 l', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco, 2,0l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco (0,75 l) ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco s0,7l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco (0,7 l) ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 2,0 l 2,0 l', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 1,6 l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco - 0,7 l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0,3 l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco 0,75l (O)', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco, 0,2l ', {'entities': [[0, 9, 'Ing']]}],
#  ['Lambrusco1,5 l ', {'entities': [[0, 10, 'Ing']]}],
#  ['Lambrusco 0,7l 9,8%', {'entities': [[0, 9, 'Ing']]}],
#  ['Eierreis mit kross gebackener Ente ',
#   {'entities': [[0, 8, 'Ing'], [30, 34, 'Ing']]}],
#  ['Tortellini alla Panna mit Schinken, in Sahnesauce',
#   {'entities': [[0, 10, 'Ing'], [26, 34, 'Ing'], [39, 49, 'Ing']]}],
#  ['Tortellini alla Panna mit Schinken in Sahnesauce',
#   {'entities': [[0, 10, 'Ing'], [26, 34, 'Ing'], [38, 48, 'Ing']]}],
#  ['10 x Tortellini alla Panna mit Schinken in Sahnesauce',
#   {'entities': [[5, 15, 'Ing'], [31, 39, 'Ing'], [43, 53, 'Ing']]}],
#  ['Hähnchenbrustfilet ', {'entities': [[0, 18, 'Ing']]}],
#  ['2 Hähnchenbrustfilet ', {'entities': [[2, 20, 'Ing']]}],
#  ['Hähnchenbrustfilet 250g ', {'entities': [[0, 18, 'Ing']]}],
#  ['Hähnchenbrustfilet 300g ', {'entities': [[0, 18, 'Ing']]}],
#  ['Hähnchenbrustfilet [L] ', {'entities': [[0, 18, 'Ing']]}],
#  ['Hähnchenbrustfilet 200g ', {'entities': [[0, 18, 'Ing']]}],
#  ['Hähnchenbrustfilet [S] ', {'entities': [[0, 18, 'Ing']]}],
#  ['Spaghetti Bolognese mit Bolognesesauce',
#   {'entities': [[0, 9, 'Ing'], [10, 19, 'Ing'], [24, 38, 'Ing']]}],
#  ['Spaghetti Bolognese mit Bolognesesauce ',
#   {'entities': [[0, 9, 'Ing'], [10, 19, 'Ing'], [24, 38, 'Ing']]}],
#  ['Spaghetti (Bolognese) mit Bolognesesauce',
#   {'entities': [[0, 9, 'Ing'], [11, 20, 'Ing'], [26, 40, 'Ing']]}],
#  ['Pizza Schinken und Mozzarella [Normal, Ø 28cm] ',
#   {'entities': [[0, 5, 'Ing'], [6, 14, 'Ing'], [19, 29, 'Ing']]}],
#  ['Omelett mit Formfleisch-Truthahnschinken, Zwiebeln und Salat ',
#   {'entities': [[0, 7, 'Ing'],
#     [12, 23, 'Ing'],
#     [24, 40, 'Ing'],
#     [42, 50, 'Ing'],
#     [55, 60, 'Ing']]}],
#  ['Maccheroni Apropos mit Gorgonzola und Sahnesauce',
#   {'entities': [[0, 10, 'Ing'], [23, 33, 'Ing'], [38, 48, 'Ing']]}],
#  ['Pizza Salami Funghi mit Salami und Pilzen',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [13, 19, 'Ing'],
#     [24, 30, 'Ing'],
#     [35, 41, 'Ing']]}],
#  ['Pizza Salami-Funghi mit Salami und Pilzen',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [13, 19, 'Ing'],
#     [24, 30, 'Ing'],
#     [35, 41, 'Ing']]}],
#  ['Pizza Salami e Funghi mit Salami und Pilzen',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [15, 21, 'Ing'],
#     [26, 32, 'Ing'],
#     [37, 43, 'Ing']]}],
#  ['Pizza Salami è Funghi mit Salami und Pilzen',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [15, 21, 'Ing'],
#     [26, 32, 'Ing'],
#     [37, 43, 'Ing']]}],
#  ['Pizza Salami & Funghi mit Salami und Pilzen',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [15, 21, 'Ing'],
#     [26, 32, 'Ing'],
#     [37, 43, 'Ing']]}],
#  ['Pizza Salami Funghi, Ø 26cm mit Salami und Pilzen',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [13, 19, 'Ing'],
#     [32, 38, 'Ing'],
#     [43, 49, 'Ing']]}],
#  ['Pizza Salami Funghi [M] mit Salami und Pilzen',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [13, 19, 'Ing'],
#     [28, 34, 'Ing'],
#     [39, 45, 'Ing']]}],
#  ['Pizza Salami Funghi [L] mit Salami und Pilzen',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [13, 19, 'Ing'],
#     [28, 34, 'Ing'],
#     [39, 45, 'Ing']]}],
#  ['Pizza Salami Funghi [S] mit Salami und Pilzen',
#   {'entities': [[0, 5, 'Ing'],
#     [6, 12, 'Ing'],
#     [13, 19, 'Ing'],
#     [28, 34, 'Ing'],
#     [39, 45, 'Ing']]}],
#  ['Pizza mit Salami, Hinterschinken, Hackfleisch, Champignons und Zwiebeln [Party, 40cm x 60cm] ',
#   {'entities': [[0, 5, 'Ing'],
#     [10, 16, 'Ing'],
#     [18, 32, 'Ing'],
#     [34, 45, 'Ing'],
#     [47, 58, 'Ing'],
#     [63, 71, 'Ing']]}],
#  ['Tacos original mexikanische Paprika, Hackfleisch, mit Käse überbacken',
#   {'entities': [[0, 5, 'Ing'],
#     [28, 35, 'Ing'],
#     [37, 48, 'Ing'],
#     [54, 58, 'Ing']]}],
#  ['Pizza Miami [Klein, Ø 26cm] mit Hähnchenfleisch, Ananas und Mais',
#   {'entities': [[0, 5, 'Ing'],
#     [32, 47, 'Ing'],
#     [49, 55, 'Ing'],
#     [60, 64, 'Ing']]}],
#  ['Pizza Frutti di Mare [Normal, Ø 30cm] mit verschiedenen Meeresfrüchten',
#   {'entities': [[0, 5, 'Ing'], [6, 20, 'Ing'], [56, 70, 'Ing']]}],
#  ...]

# %%
df_result.apply(lambda )
# Out:
#                                                     text  \
# 0                                           Sprite 1,0l
# 1                                          Sprite 0,33l
# 2                                           Sprite 1.5l
# 3                                             Sprite 1l
# 4                                           Sprite 0,5l
# ...                                                  ...
# 12972  Ben & Jerry's Strawberry Cheesecake 500ml Erdb...
# 12973  Ben & Jerry's Strawberry Cheesecake 100ml Erdb...
# 12974  Ben & Jerry's Strawberry Cheesecake 500ml Erdb...
# 12975  Ouzo Spezial-Teller mit Gyros, Schnitzel, Hähn...
# 12976  Ben & Jerry's Blondie Brownie 500ml Vanille- &...
#
#                                                 entities  match_all
# 0                                        [[0, 6, Brand]]          1
# 1                                        [[0, 6, Brand]]          1
# 2                                        [[0, 6, Brand]]          1
# 3                                        [[0, 6, Brand]]          1
# 4                                        [[0, 6, Brand]]          1
# ...                                                  ...        ...
# 12972  [[0, 11, Brand], [14, 35, Flavor], [115, 126, ...          1
# 12973  [[0, 11, Brand], [14, 35, Flavor], [115, 126, ...          1
# 12974  [[0, 11, Brand], [14, 35, Flavor], [114, 125, ...          1
# 12975  [[0, 4, Ing], [24, 29, Ing], [31, 40, Ing], [4...          1
# 12976  [[0, 11, Brand], [14, 29, Flavor], [159, 170, ...          1
#
# [12977 rows x 3 columns]
